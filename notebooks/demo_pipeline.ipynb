# %% [markdown]
# # Milestone 2 Pipeline Demonstration
# This notebook demonstrates the end-to-end functionality of the shawwaf machine vision pipeline.

# %%
# !pip install mrmr-selection
# Out:
# ^C
# ...
#   Using cached mrmr_selection-0.2.8-py3-none-any.whl.metadata (6.6 kB)
# ...
#   Using cached category_encoders-2.9.0-py3-none-any.whl.metadata (7.9 kB)
# ...
#   Using cached patsy-1.0.2-py2.py3-none-any.whl.metadata (3.6 kB)
# ...
#   Using cached statsmodels-0.14.6-cp314-cp314-win_amd64.whl.metadata (9.8 kB)
# ...
#    ---------------------------------------- 0.0/824.0 kB ? eta -:--:--
#    ---------------------------------------- 0.0/824.0 kB ? eta -:--:--
#    ---------------------------------------- 0.0/824.0 kB ? eta -:--:--
#    ---------------------------------------- 0.0/824.0 kB ? eta -:--:--
#    ---------------------------------------- 0.0/824.0 kB ? eta -:--:--
#    ---------------------------------------- 0.0/824.0 kB ? eta -:--:--
#    ---------------------------------------- 0.0/824.0 kB ? eta -:--:--
#    ---------------------------------------- 0.0/824.0 kB ? eta -:--:--
#    ---------------------------------------- 0.0/824.0 kB ? eta -:--:--
# ...

# %%
import sys
import os
sys.path.append(os.path.abspath('..'))
from scripts.run_pipeline import main
main()
# Out:
# Building and splitting dataset...
# Setting up transforms...
# Generating augmentation panel...
# Extracting features...
# 100%|██████████| 16/16 [00:02<00:00,  6.92it/s]
# Training models...
# ...Softmax...
# Comparing models...
# Done!
